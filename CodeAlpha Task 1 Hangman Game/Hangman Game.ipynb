# %%
import random
from words import word_list


def get_word():
    word = random.choice(word_list)
    return word.upper()


def play(word):
    word_completion = "_" * len(word)
    guessed = False
    guessed_letters = []
    guessed_words = []
    tries = 6
    print("Let's play Hangman!")
    print(display_hangman(tries))
    print(word_completion)
    print("\n")
    while not guessed and tries > 0:
        guess = input("Guess a letter or word: ").upper()
        if len(guess) == 1 and guess.isalpha():
            if guess in guessed_letters:
                print("You already guessed the letter", guess)
            elif guess not in word:
                print("OOPS, ", guess, "is not in the word.")
                tries -= 1
                guessed_letters.append(guess)
            else:
                print("GREAT, ", guess, "is in the word!")
                guessed_letters.append(guess)
                word_as_list = list(word_completion)
                indices = [i for i, letter in enumerate(word) if letter == guess]
                for index in indices:
                    word_as_list[index] = guess
                word_completion = "".join(word_as_list)
                if "_" not in word_completion:
                    guessed = True
        elif len(guess) == len(word) and guess.isalpha():
            if guess in guessed_words:
                print("You already guessed the word", guess)
            elif guess != word:
                print(guess, "is not the word.")
                tries -= 1
                guessed_words.append(guess)
            else:
                guessed = True
                word_completion = word
        else:
            print("Not a valid guess.")
        print(display_hangman(tries))
        print(word_completion)
        print("\n")
    if guessed:
        print("Congratulations!, You guessed the word! You won!")
    else:
        print("Good Try!,but You missed the word. The word is " + word + ". Try in the next time!")


def display_hangman(tries):
    stages = [  # 0
                """
                   --------
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |     / \\
                   -
                """,
                # 1
                """
                   --------
                   |      |
                   |      O
                   |     \|/
                   |      |
                   |     / 
                   -
                """,
                # 2
                """
                   --------
                   |      |
                   |      O
                   |     \|/
                   |      |
                   |      
                   -
                """,
                # 3
                """
                   --------
                   |      |
                   |      O
                   |     \|
                   |      |
                   |     
                   -
                """,
                # 4
                """
                   --------
                   |      |
                   |      O
                   |      |
                   |      |
                   |     
                   -
                """,
                # 5
                """
                   --------
                   |      |
                   |      O
                   |    
                   |      
                   |     
                   -
                """,
                # 6
                """
                   --------
                   |      |
                   |      
                   |    
                   |      
                   |     
                   -
                """
    ]
    return stages[tries]


def main():
    word = get_word()
    play(word)
    while input("Play Again? (Y/N) ").upper() == "Y":
        word = get_word()
        play(word)


if __name__ == "__main__":
    main()
# Out:
# Let's play Hangman!
#
#                    --------
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                    -
#
# ________
#
#
# Guess a letter or word: M
# GREAT,  M is in the word!
#
#                    --------
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                    -
#
# M_______
#
#
# Guess a letter or word: A
# GREAT,  A is in the word!
#
#                    --------
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                    -
#
# M____A__
#
#
# Guess a letter or word: I
# GREAT,  I is in the word!
#
#                    --------
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                    -
#
# M____AI_
#
#
# Guess a letter or word: N
# GREAT,  N is in the word!
#
#                    --------
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                    -
#
# M__N_AIN
#
#
# Guess a letter or word: T
# GREAT,  T is in the word!
#
#                    --------
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                    -
#
# M__NTAIN
#
#
# Guess a letter or word: O
# GREAT,  O is in the word!
#
#                    --------
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                    -
#
# MO_NTAIN
#
#
# Guess a letter or word: U
# GREAT,  U is in the word!
#
#                    --------
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                    -
#
# MOUNTAIN
#
#
# Congratulations!, You guessed the word! You won!
# Play Again? (Y/N) Y
# Let's play Hangman!
#
#                    --------
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                    -
#
# _______
#
#
# Guess a letter or word: L
# GREAT,  L is in the word!
#
#                    --------
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                    -
#
# __L____
#
#
# Guess a letter or word: J
# OOPS,  J is not in the word.
#
#                    --------
#                    |      |
#                    |      O
#                    |
#                    |
#                    |
#                    -
#
# __L____
#
#
# Guess a letter or word: P
# OOPS,  P is not in the word.
#
#                    --------
#                    |      |
#                    |      O
#                    |      |
#                    |      |
#                    |
#                    -
#
# __L____
#
#
# Guess a letter or word: P
# You already guessed the letter P
#
#                    --------
#                    |      |
#                    |      O
#                    |      |
#                    |      |
#                    |
#                    -
#
# __L____
#
#
# Guess a letter or word: O
# OOPS,  O is not in the word.
#
#                    --------
#                    |      |
#                    |      O
#                    |     \|
#                    |      |
#                    |
#                    -
#
# __L____
#
#
# Guess a letter or word: E
# GREAT,  E is in the word!
#
#                    --------
#                    |      |
#                    |      O
#                    |     \|
#                    |      |
#                    |
#                    -
#
# __LE__E
#
#
# Guess a letter or word: V
# OOPS,  V is not in the word.
#
#                    --------
#                    |      |
#                    |      O
#                    |     \|/
#                    |      |
#                    |
#                    -
#
# __LE__E
#
#
# Guess a letter or word: X
# OOPS,  X is not in the word.
#
#                    --------
#                    |      |
#                    |      O
#                    |     \|/
#                    |      |
#                    |     /
#                    -
#
# __LE__E
#
#
# Guess a letter or word: Z
# OOPS,  Z is not in the word.
#
#                    --------
#                    |      |
#                    |      O
#                    |     \|/
#                    |      |
#                    |     / \
#                    -
#
# __LE__E
#
#
# Good Try!,but You missed the word. The word is SILENCE. Try in the next time!
# Play Again? (Y/N) N
